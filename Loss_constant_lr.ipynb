# %%
# !pip install tensorflow-gpu==2.0.0-beta1
# Out:
# Collecting tensorflow-gpu==2.0.0-beta1
#   Downloading https://files.pythonhosted.org/packages/2b/53/e18c5e7a2263d3581a979645a185804782e59b8e13f42b9c3c3cfb5bb503/tensorflow_gpu-2.0.0b1-cp36-cp36m-manylinux1_x86_64.whl (348.9MB)
#      |████████████████████████████████| 348.9MB 141kB/s
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.16.5)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.1.7)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.0.8)
# Collecting tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 (from tensorflow-gpu==2.0.0-beta1)
#   Downloading https://files.pythonhosted.org/packages/32/dd/99c47dd007dcf10d63fd895611b063732646f23059c618a373e85019eb0e/tf_estimator_nightly-1.14.0.dev2019060501-py2.py3-none-any.whl (496kB)
#      |████████████████████████████████| 501kB 47.5MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.8.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.33.6)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-beta1) (0.3.2)
# Collecting tb-nightly<1.14.0a20190604,>=1.14.0a20190603 (from tensorflow-gpu==2.0.0-beta1)
#   Downloading https://files.pythonhosted.org/packages/a4/96/571b875cd81dda9d5dfa1422a4f9d749e67c0a8d4f4f0b33a4e5f5f35e27/tb_nightly-1.14.0a20190603-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 36.9MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-beta1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-beta1) (41.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow-gpu==2.0.0-beta1) (0.16.0)
# Installing collected packages: tf-estimator-nightly, tb-nightly, tensorflow-gpu
# Successfully installed tb-nightly-1.14.0a20190603 tensorflow-gpu-2.0.0b1 tf-estimator-nightly-1.14.0.dev2019060501

# %%
from __future__ import print_function
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
import numpy as np
import os
import tensorflow as tf

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 200
data_augmentation = False
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 5e-3
    if epoch > 180:
        lr *= 0.5e-1
    elif epoch > 160:
        lr *= 1e-1
    elif epoch > 120:
        lr *= 1e-1
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(momentum=.9,lr=1e-3),
              metrics=['categorical_crossentropy','accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
#save_dir = os.path.join(os.getcwd(), 'saved_models')
#model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
#if not os.path.isdir(save_dir):
#    os.makedirs(save_dir)
#filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
#checkpoint = ModelCheckpoint(filepath=filepath,
#                             monitor='val_acc',
#                             verbose=1,
#                             save_best_only=True)

#lr_scheduler = LearningRateScheduler(lr_schedule)

#lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
#                               cooldown=0,
#                               patience=5,
#                               min_lr=0.5e-6)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 16)   64          conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 16)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 16)   272         activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 16)   64          conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 16)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 16)   2320        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 16)   64          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 16)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 64)   1088        activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 64)   1088        activation_30[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 64)   0           conv2d_35[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 64)   256         add_9[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 16)   1040        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 16)   64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 16)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 16)   2320        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 16)   64          conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 16)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 64)   1088        activation_33[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 64)   0           add_9[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 64)   256         add_10[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 16)   1040        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 16)   64          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 16)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 16)   2320        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 32, 32, 16)   64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 16)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 64)   1088        activation_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 64)   0           add_10[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 64)   256         add_11[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 64)   4160        activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 16, 16, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 64)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 64)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 16, 16, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 128)  8320        add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 128)  8320        activation_39[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 128)  0           conv2d_45[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 16, 16, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 64)   8256        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 16, 16, 64)   256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 64)   36928       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 64)   256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 128)  8320        activation_42[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 128)  0           add_12[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 128)  512         add_13[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 128)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 64)   8256        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 64)   256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 64)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 64)   36928       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 16, 64)   256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 16, 16, 64)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 128)  8320        activation_45[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 128)  0           add_13[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 128)  512         add_14[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 128)    16512       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 8, 8, 128)    512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 128)    147584      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 8, 8, 128)    512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 256)    33024       add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 256)    33024       activation_48[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 256)    0           conv2d_55[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8, 8, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 256)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 128)    32896       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8, 8, 128)    512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 128)    147584      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 128)    512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 256)    33024       activation_51[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           add_15[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 256)    1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 256)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 8, 8, 128)    32896       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 128)    512         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 128)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 128)    147584      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 128)    512         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 256)    33024       activation_54[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           add_16[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 256)    1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 256)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           activation_55[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        flatten_1[0][0]
# ==================================================================================================
# Total params: 849,002
# Trainable params: 843,786
# Non-trainable params: 5,216
# __________________________________________________________________________________________________
# ResNet29v2

# %%
"""def scheduler(epoch):
  if epoch >=250:
    return 1e-4
  else:
    return 1e-3

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)"""
history=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=250,
              validation_data=(x_test, y_test),
              shuffle=True)
#history=model.fit(x_train, y_train,
#              batch_size=batch_size,
#              epochs=250,
#              validation_data=(x_test, y_test),
#              shuffle=True)

# %%
plt.plot(range(0,400), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,400), history.history['loss'], '-ok',c='r');

# %%
plt.plot(range(0,400), history.history['val_accuracy'], '-ok',c='g');
plt.plot(range(0,400), history.history['accuracy'], '-ok',c='r');

# %%
#lr=1e-3 from 0 to 249 then 1e-4
plt.plot(range(0,400), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,400), history.history['loss'], '-ok',c='r');

# %%
plt.plot(range(0,400), history.history['val_accuracy'], '-ok',c='g');
plt.plot(range(0,400), history.history['accuracy'], '-ok',c='r');

# %%
def scheduler(epoch):
  if epoch >=70:
    return 1e-5
  elif epoch >=20:
    return 1e-4
  else:
    return 5e-3

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
history=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=150,
              validation_data=(x_test, y_test),
              callbacks=[callback],
              shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/150
# 50000/50000 [==============================] - 77s 2ms/sample - loss: 2.4728 - categorical_crossentropy: 1.8655 - accuracy: 0.3215 - val_loss: 2.3443 - val_categorical_crossentropy: 1.7394 - val_accuracy: 0.3485
# Epoch 2/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.1726 - categorical_crossentropy: 1.5701 - accuracy: 0.4255 - val_loss: 2.1345 - val_categorical_crossentropy: 1.5343 - val_accuracy: 0.4396
# Epoch 3/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.0298 - categorical_crossentropy: 1.4320 - accuracy: 0.4813 - val_loss: 2.0232 - val_categorical_crossentropy: 1.4278 - val_accuracy: 0.4867
# Epoch 4/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.9196 - categorical_crossentropy: 1.3265 - accuracy: 0.5232 - val_loss: 1.9048 - val_categorical_crossentropy: 1.3141 - val_accuracy: 0.5135
# Epoch 5/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.8314 - categorical_crossentropy: 1.2430 - accuracy: 0.5547 - val_loss: 1.8530 - val_categorical_crossentropy: 1.2669 - val_accuracy: 0.5374
# Epoch 6/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7584 - categorical_crossentropy: 1.1745 - accuracy: 0.5772 - val_loss: 1.8311 - val_categorical_crossentropy: 1.2495 - val_accuracy: 0.5358
# Epoch 7/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6993 - categorical_crossentropy: 1.1200 - accuracy: 0.6001 - val_loss: 1.7399 - val_categorical_crossentropy: 1.1629 - val_accuracy: 0.5786
# Epoch 8/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6456 - categorical_crossentropy: 1.0707 - accuracy: 0.6171 - val_loss: 1.7254 - val_categorical_crossentropy: 1.1527 - val_accuracy: 0.5857
# Epoch 9/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5912 - categorical_crossentropy: 1.0207 - accuracy: 0.6365 - val_loss: 1.6880 - val_categorical_crossentropy: 1.1197 - val_accuracy: 0.5937
# Epoch 10/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5386 - categorical_crossentropy: 0.9724 - accuracy: 0.6514 - val_loss: 1.6750 - val_categorical_crossentropy: 1.1109 - val_accuracy: 0.6029
# Epoch 11/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.4919 - categorical_crossentropy: 0.9300 - accuracy: 0.6700 - val_loss: 1.6257 - val_categorical_crossentropy: 1.0659 - val_accuracy: 0.6228
# Epoch 12/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4425 - categorical_crossentropy: 0.8848 - accuracy: 0.6843 - val_loss: 1.6244 - val_categorical_crossentropy: 1.0688 - val_accuracy: 0.6206
# Epoch 13/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3952 - categorical_crossentropy: 0.8416 - accuracy: 0.7023 - val_loss: 1.8637 - val_categorical_crossentropy: 1.3122 - val_accuracy: 0.5571
# Epoch 14/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3507 - categorical_crossentropy: 0.8012 - accuracy: 0.7144 - val_loss: 1.5390 - val_categorical_crossentropy: 0.9916 - val_accuracy: 0.6505
# Epoch 15/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.3036 - categorical_crossentropy: 0.7582 - accuracy: 0.7318 - val_loss: 1.7160 - val_categorical_crossentropy: 1.1725 - val_accuracy: 0.6007
# Epoch 16/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2568 - categorical_crossentropy: 0.7153 - accuracy: 0.7482 - val_loss: 1.6009 - val_categorical_crossentropy: 1.0612 - val_accuracy: 0.6418
# Epoch 17/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.2114 - categorical_crossentropy: 0.6736 - accuracy: 0.7620 - val_loss: 1.4696 - val_categorical_crossentropy: 0.9336 - val_accuracy: 0.6799
# Epoch 18/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1651 - categorical_crossentropy: 0.6311 - accuracy: 0.7763 - val_loss: 1.8355 - val_categorical_crossentropy: 1.3032 - val_accuracy: 0.5738
# Epoch 19/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.1205 - categorical_crossentropy: 0.5900 - accuracy: 0.7918 - val_loss: 1.5365 - val_categorical_crossentropy: 1.0076 - val_accuracy: 0.6681
# Epoch 20/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0812 - categorical_crossentropy: 0.5540 - accuracy: 0.8057 - val_loss: 1.5449 - val_categorical_crossentropy: 1.0194 - val_accuracy: 0.6596
# Epoch 21/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 1.0223 - categorical_crossentropy: 0.4969 - accuracy: 0.8302 - val_loss: 1.3806 - val_categorical_crossentropy: 0.8552 - val_accuracy: 0.7075
# Epoch 22/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9342 - categorical_crossentropy: 0.4088 - accuracy: 0.8692 - val_loss: 1.3680 - val_categorical_crossentropy: 0.8427 - val_accuracy: 0.7147
# Epoch 23/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9213 - categorical_crossentropy: 0.3960 - accuracy: 0.8750 - val_loss: 1.3680 - val_categorical_crossentropy: 0.8428 - val_accuracy: 0.7147
# Epoch 24/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9126 - categorical_crossentropy: 0.3874 - accuracy: 0.8782 - val_loss: 1.3684 - val_categorical_crossentropy: 0.8433 - val_accuracy: 0.7160
# Epoch 25/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.9045 - categorical_crossentropy: 0.3795 - accuracy: 0.8810 - val_loss: 1.3670 - val_categorical_crossentropy: 0.8420 - val_accuracy: 0.7149
# Epoch 26/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8988 - categorical_crossentropy: 0.3738 - accuracy: 0.8843 - val_loss: 1.3687 - val_categorical_crossentropy: 0.8438 - val_accuracy: 0.7154
# Epoch 27/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8937 - categorical_crossentropy: 0.3688 - accuracy: 0.8848 - val_loss: 1.3707 - val_categorical_crossentropy: 0.8459 - val_accuracy: 0.7133
# Epoch 28/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8881 - categorical_crossentropy: 0.3634 - accuracy: 0.8891 - val_loss: 1.3725 - val_categorical_crossentropy: 0.8477 - val_accuracy: 0.7134
# Epoch 29/150
# 50000/50000 [==============================] - 68s 1ms/sample - loss: 0.8837 - categorical_crossentropy: 0.3590 - accuracy: 0.8906 - val_loss: 1.3756 - val_categorical_crossentropy: 0.8509 - val_accuracy: 0.7134
# Epoch 30/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8816 - categorical_crossentropy: 0.3570 - accuracy: 0.8903 - val_loss: 1.3758 - val_categorical_crossentropy: 0.8513 - val_accuracy: 0.7128
# Epoch 31/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8774 - categorical_crossentropy: 0.3529 - accuracy: 0.8922 - val_loss: 1.3775 - val_categorical_crossentropy: 0.8530 - val_accuracy: 0.7143
# Epoch 32/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8759 - categorical_crossentropy: 0.3515 - accuracy: 0.8925 - val_loss: 1.3793 - val_categorical_crossentropy: 0.8550 - val_accuracy: 0.7129
# Epoch 33/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8710 - categorical_crossentropy: 0.3467 - accuracy: 0.8941 - val_loss: 1.3820 - val_categorical_crossentropy: 0.8578 - val_accuracy: 0.7134
# Epoch 34/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8656 - categorical_crossentropy: 0.3414 - accuracy: 0.8964 - val_loss: 1.3848 - val_categorical_crossentropy: 0.8607 - val_accuracy: 0.7139
# Epoch 35/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8629 - categorical_crossentropy: 0.3388 - accuracy: 0.8982 - val_loss: 1.3870 - val_categorical_crossentropy: 0.8629 - val_accuracy: 0.7109
# Epoch 36/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8593 - categorical_crossentropy: 0.3353 - accuracy: 0.8984 - val_loss: 1.3886 - val_categorical_crossentropy: 0.8646 - val_accuracy: 0.7123
# Epoch 37/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8566 - categorical_crossentropy: 0.3327 - accuracy: 0.8995 - val_loss: 1.3914 - val_categorical_crossentropy: 0.8676 - val_accuracy: 0.7116
# Epoch 38/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8535 - categorical_crossentropy: 0.3297 - accuracy: 0.9001 - val_loss: 1.3936 - val_categorical_crossentropy: 0.8699 - val_accuracy: 0.7118
# Epoch 39/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8519 - categorical_crossentropy: 0.3282 - accuracy: 0.9007 - val_loss: 1.3963 - val_categorical_crossentropy: 0.8726 - val_accuracy: 0.7118
# Epoch 40/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8474 - categorical_crossentropy: 0.3238 - accuracy: 0.9031 - val_loss: 1.3976 - val_categorical_crossentropy: 0.8740 - val_accuracy: 0.7096
# Epoch 41/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8463 - categorical_crossentropy: 0.3228 - accuracy: 0.9030 - val_loss: 1.3977 - val_categorical_crossentropy: 0.8742 - val_accuracy: 0.7119
# Epoch 42/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8420 - categorical_crossentropy: 0.3186 - accuracy: 0.9048 - val_loss: 1.4031 - val_categorical_crossentropy: 0.8797 - val_accuracy: 0.7097
# Epoch 43/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8386 - categorical_crossentropy: 0.3152 - accuracy: 0.9062 - val_loss: 1.4031 - val_categorical_crossentropy: 0.8798 - val_accuracy: 0.7098
# Epoch 44/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8374 - categorical_crossentropy: 0.3141 - accuracy: 0.9066 - val_loss: 1.4072 - val_categorical_crossentropy: 0.8839 - val_accuracy: 0.7091
# Epoch 45/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8346 - categorical_crossentropy: 0.3114 - accuracy: 0.9086 - val_loss: 1.4119 - val_categorical_crossentropy: 0.8888 - val_accuracy: 0.7098
# Epoch 46/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8332 - categorical_crossentropy: 0.3101 - accuracy: 0.9071 - val_loss: 1.4086 - val_categorical_crossentropy: 0.8856 - val_accuracy: 0.7111
# Epoch 47/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8291 - categorical_crossentropy: 0.3061 - accuracy: 0.9097 - val_loss: 1.4134 - val_categorical_crossentropy: 0.8905 - val_accuracy: 0.7073
# Epoch 48/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8259 - categorical_crossentropy: 0.3030 - accuracy: 0.9110 - val_loss: 1.4164 - val_categorical_crossentropy: 0.8936 - val_accuracy: 0.7084
# Epoch 49/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8230 - categorical_crossentropy: 0.3002 - accuracy: 0.9111 - val_loss: 1.4203 - val_categorical_crossentropy: 0.8975 - val_accuracy: 0.7072
# Epoch 50/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8205 - categorical_crossentropy: 0.2978 - accuracy: 0.9117 - val_loss: 1.4203 - val_categorical_crossentropy: 0.8977 - val_accuracy: 0.7065
# Epoch 51/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8196 - categorical_crossentropy: 0.2970 - accuracy: 0.9133 - val_loss: 1.4230 - val_categorical_crossentropy: 0.9004 - val_accuracy: 0.7070
# Epoch 52/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8175 - categorical_crossentropy: 0.2949 - accuracy: 0.9127 - val_loss: 1.4225 - val_categorical_crossentropy: 0.9001 - val_accuracy: 0.7086
# Epoch 53/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8126 - categorical_crossentropy: 0.2901 - accuracy: 0.9146 - val_loss: 1.4256 - val_categorical_crossentropy: 0.9032 - val_accuracy: 0.7083
# Epoch 54/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8119 - categorical_crossentropy: 0.2896 - accuracy: 0.9164 - val_loss: 1.4315 - val_categorical_crossentropy: 0.9092 - val_accuracy: 0.7053
# Epoch 55/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8088 - categorical_crossentropy: 0.2865 - accuracy: 0.9163 - val_loss: 1.4323 - val_categorical_crossentropy: 0.9101 - val_accuracy: 0.7067
# Epoch 56/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8081 - categorical_crossentropy: 0.2859 - accuracy: 0.9170 - val_loss: 1.4345 - val_categorical_crossentropy: 0.9124 - val_accuracy: 0.7078
# Epoch 57/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8049 - categorical_crossentropy: 0.2828 - accuracy: 0.9177 - val_loss: 1.4344 - val_categorical_crossentropy: 0.9124 - val_accuracy: 0.7094
# Epoch 58/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8026 - categorical_crossentropy: 0.2806 - accuracy: 0.9179 - val_loss: 1.4364 - val_categorical_crossentropy: 0.9145 - val_accuracy: 0.7053
# Epoch 59/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7988 - categorical_crossentropy: 0.2770 - accuracy: 0.9217 - val_loss: 1.4382 - val_categorical_crossentropy: 0.9164 - val_accuracy: 0.7065
# Epoch 60/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7947 - categorical_crossentropy: 0.2729 - accuracy: 0.9211 - val_loss: 1.4418 - val_categorical_crossentropy: 0.9200 - val_accuracy: 0.7056
# Epoch 61/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7937 - categorical_crossentropy: 0.2720 - accuracy: 0.9222 - val_loss: 1.4466 - val_categorical_crossentropy: 0.9249 - val_accuracy: 0.7039
# Epoch 62/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7885 - categorical_crossentropy: 0.2669 - accuracy: 0.9248 - val_loss: 1.4475 - val_categorical_crossentropy: 0.9260 - val_accuracy: 0.7046
# Epoch 63/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7882 - categorical_crossentropy: 0.2667 - accuracy: 0.9258 - val_loss: 1.4517 - val_categorical_crossentropy: 0.9303 - val_accuracy: 0.7045
# Epoch 64/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7872 - categorical_crossentropy: 0.2658 - accuracy: 0.9254 - val_loss: 1.4519 - val_categorical_crossentropy: 0.9306 - val_accuracy: 0.7043
# Epoch 65/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7840 - categorical_crossentropy: 0.2627 - accuracy: 0.9257 - val_loss: 1.4523 - val_categorical_crossentropy: 0.9310 - val_accuracy: 0.7053
# Epoch 66/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7816 - categorical_crossentropy: 0.2604 - accuracy: 0.9259 - val_loss: 1.4588 - val_categorical_crossentropy: 0.9376 - val_accuracy: 0.7039
# Epoch 67/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7795 - categorical_crossentropy: 0.2584 - accuracy: 0.9260 - val_loss: 1.4589 - val_categorical_crossentropy: 0.9378 - val_accuracy: 0.7057
# Epoch 68/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7743 - categorical_crossentropy: 0.2533 - accuracy: 0.9276 - val_loss: 1.4604 - val_categorical_crossentropy: 0.9394 - val_accuracy: 0.7036
# Epoch 69/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7769 - categorical_crossentropy: 0.2559 - accuracy: 0.9278 - val_loss: 1.4646 - val_categorical_crossentropy: 0.9437 - val_accuracy: 0.7025
# Epoch 70/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7734 - categorical_crossentropy: 0.2525 - accuracy: 0.9288 - val_loss: 1.4726 - val_categorical_crossentropy: 0.9518 - val_accuracy: 0.7013
# Epoch 71/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7681 - categorical_crossentropy: 0.2473 - accuracy: 0.9310 - val_loss: 1.4660 - val_categorical_crossentropy: 0.9452 - val_accuracy: 0.7028
# Epoch 72/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7672 - categorical_crossentropy: 0.2464 - accuracy: 0.9326 - val_loss: 1.4659 - val_categorical_crossentropy: 0.9451 - val_accuracy: 0.7023
# Epoch 73/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7682 - categorical_crossentropy: 0.2474 - accuracy: 0.9320 - val_loss: 1.4660 - val_categorical_crossentropy: 0.9452 - val_accuracy: 0.7031
# Epoch 74/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7681 - categorical_crossentropy: 0.2473 - accuracy: 0.9325 - val_loss: 1.4655 - val_categorical_crossentropy: 0.9447 - val_accuracy: 0.7017
# Epoch 75/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7666 - categorical_crossentropy: 0.2458 - accuracy: 0.9329 - val_loss: 1.4660 - val_categorical_crossentropy: 0.9452 - val_accuracy: 0.7023
# Epoch 76/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7656 - categorical_crossentropy: 0.2448 - accuracy: 0.9335 - val_loss: 1.4676 - val_categorical_crossentropy: 0.9469 - val_accuracy: 0.7029
# Epoch 77/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7668 - categorical_crossentropy: 0.2460 - accuracy: 0.9323 - val_loss: 1.4682 - val_categorical_crossentropy: 0.9475 - val_accuracy: 0.7033
# Epoch 78/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7662 - categorical_crossentropy: 0.2455 - accuracy: 0.9321 - val_loss: 1.4677 - val_categorical_crossentropy: 0.9469 - val_accuracy: 0.7026
# Epoch 79/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7658 - categorical_crossentropy: 0.2450 - accuracy: 0.9324 - val_loss: 1.4681 - val_categorical_crossentropy: 0.9474 - val_accuracy: 0.7030
# Epoch 80/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7666 - categorical_crossentropy: 0.2459 - accuracy: 0.9308 - val_loss: 1.4683 - val_categorical_crossentropy: 0.9476 - val_accuracy: 0.7026
# Epoch 81/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7660 - categorical_crossentropy: 0.2453 - accuracy: 0.9329 - val_loss: 1.4690 - val_categorical_crossentropy: 0.9483 - val_accuracy: 0.7031
# Epoch 82/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7649 - categorical_crossentropy: 0.2442 - accuracy: 0.9335 - val_loss: 1.4684 - val_categorical_crossentropy: 0.9477 - val_accuracy: 0.7033
# Epoch 83/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7659 - categorical_crossentropy: 0.2452 - accuracy: 0.9328 - val_loss: 1.4695 - val_categorical_crossentropy: 0.9488 - val_accuracy: 0.7016
# Epoch 84/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7647 - categorical_crossentropy: 0.2440 - accuracy: 0.9338 - val_loss: 1.4690 - val_categorical_crossentropy: 0.9484 - val_accuracy: 0.7021
# Epoch 85/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7642 - categorical_crossentropy: 0.2435 - accuracy: 0.9339 - val_loss: 1.4694 - val_categorical_crossentropy: 0.9487 - val_accuracy: 0.7027
# Epoch 86/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7631 - categorical_crossentropy: 0.2424 - accuracy: 0.9339 - val_loss: 1.4688 - val_categorical_crossentropy: 0.9482 - val_accuracy: 0.7028
# Epoch 87/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7647 - categorical_crossentropy: 0.2440 - accuracy: 0.9327 - val_loss: 1.4688 - val_categorical_crossentropy: 0.9482 - val_accuracy: 0.7035
# Epoch 88/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7647 - categorical_crossentropy: 0.2441 - accuracy: 0.9323 - val_loss: 1.4699 - val_categorical_crossentropy: 0.9492 - val_accuracy: 0.7021
# Epoch 89/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7633 - categorical_crossentropy: 0.2427 - accuracy: 0.9336 - val_loss: 1.4709 - val_categorical_crossentropy: 0.9503 - val_accuracy: 0.7023
# Epoch 90/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7641 - categorical_crossentropy: 0.2434 - accuracy: 0.9332 - val_loss: 1.4701 - val_categorical_crossentropy: 0.9495 - val_accuracy: 0.7010
# Epoch 91/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7622 - categorical_crossentropy: 0.2416 - accuracy: 0.9348 - val_loss: 1.4699 - val_categorical_crossentropy: 0.9493 - val_accuracy: 0.7022
# Epoch 92/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7620 - categorical_crossentropy: 0.2414 - accuracy: 0.9335 - val_loss: 1.4706 - val_categorical_crossentropy: 0.9500 - val_accuracy: 0.7033
# Epoch 93/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7625 - categorical_crossentropy: 0.2419 - accuracy: 0.9341 - val_loss: 1.4713 - val_categorical_crossentropy: 0.9507 - val_accuracy: 0.7036
# Epoch 94/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7622 - categorical_crossentropy: 0.2416 - accuracy: 0.9341 - val_loss: 1.4707 - val_categorical_crossentropy: 0.9501 - val_accuracy: 0.7023
# Epoch 95/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7645 - categorical_crossentropy: 0.2439 - accuracy: 0.9321 - val_loss: 1.4716 - val_categorical_crossentropy: 0.9510 - val_accuracy: 0.7031
# Epoch 96/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7615 - categorical_crossentropy: 0.2410 - accuracy: 0.9348 - val_loss: 1.4721 - val_categorical_crossentropy: 0.9515 - val_accuracy: 0.7017
# Epoch 97/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7613 - categorical_crossentropy: 0.2407 - accuracy: 0.9345 - val_loss: 1.4728 - val_categorical_crossentropy: 0.9523 - val_accuracy: 0.7026
# Epoch 98/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7624 - categorical_crossentropy: 0.2418 - accuracy: 0.9334 - val_loss: 1.4725 - val_categorical_crossentropy: 0.9520 - val_accuracy: 0.7020
# Epoch 99/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7611 - categorical_crossentropy: 0.2405 - accuracy: 0.9339 - val_loss: 1.4732 - val_categorical_crossentropy: 0.9526 - val_accuracy: 0.7023
# Epoch 100/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7619 - categorical_crossentropy: 0.2414 - accuracy: 0.9329 - val_loss: 1.4727 - val_categorical_crossentropy: 0.9522 - val_accuracy: 0.7024
# Epoch 101/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7593 - categorical_crossentropy: 0.2387 - accuracy: 0.9346 - val_loss: 1.4725 - val_categorical_crossentropy: 0.9520 - val_accuracy: 0.7014
# Epoch 102/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7590 - categorical_crossentropy: 0.2384 - accuracy: 0.9354 - val_loss: 1.4737 - val_categorical_crossentropy: 0.9532 - val_accuracy: 0.7025
# Epoch 103/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7627 - categorical_crossentropy: 0.2421 - accuracy: 0.9328 - val_loss: 1.4738 - val_categorical_crossentropy: 0.9533 - val_accuracy: 0.7023
# Epoch 104/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7628 - categorical_crossentropy: 0.2423 - accuracy: 0.9337 - val_loss: 1.4741 - val_categorical_crossentropy: 0.9536 - val_accuracy: 0.7023
# Epoch 105/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7590 - categorical_crossentropy: 0.2385 - accuracy: 0.9357 - val_loss: 1.4754 - val_categorical_crossentropy: 0.9549 - val_accuracy: 0.7025
# Epoch 106/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7596 - categorical_crossentropy: 0.2391 - accuracy: 0.9354 - val_loss: 1.4741 - val_categorical_crossentropy: 0.9536 - val_accuracy: 0.7009
# Epoch 107/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7605 - categorical_crossentropy: 0.2401 - accuracy: 0.9353 - val_loss: 1.4746 - val_categorical_crossentropy: 0.9541 - val_accuracy: 0.7024
# Epoch 108/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7605 - categorical_crossentropy: 0.2400 - accuracy: 0.9348 - val_loss: 1.4746 - val_categorical_crossentropy: 0.9541 - val_accuracy: 0.7026
# Epoch 109/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7582 - categorical_crossentropy: 0.2378 - accuracy: 0.9349 - val_loss: 1.4744 - val_categorical_crossentropy: 0.9539 - val_accuracy: 0.7034
# Epoch 110/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7569 - categorical_crossentropy: 0.2365 - accuracy: 0.9355 - val_loss: 1.4756 - val_categorical_crossentropy: 0.9552 - val_accuracy: 0.7025
# Epoch 111/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7564 - categorical_crossentropy: 0.2359 - accuracy: 0.9364 - val_loss: 1.4754 - val_categorical_crossentropy: 0.9550 - val_accuracy: 0.7020
# Epoch 112/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7581 - categorical_crossentropy: 0.2377 - accuracy: 0.9355 - val_loss: 1.4763 - val_categorical_crossentropy: 0.9559 - val_accuracy: 0.7018
# Epoch 113/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7589 - categorical_crossentropy: 0.2385 - accuracy: 0.9357 - val_loss: 1.4759 - val_categorical_crossentropy: 0.9555 - val_accuracy: 0.7023
# Epoch 114/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7588 - categorical_crossentropy: 0.2384 - accuracy: 0.9351 - val_loss: 1.4768 - val_categorical_crossentropy: 0.9564 - val_accuracy: 0.7022
# Epoch 115/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7573 - categorical_crossentropy: 0.2369 - accuracy: 0.9350 - val_loss: 1.4762 - val_categorical_crossentropy: 0.9558 - val_accuracy: 0.7022
# Epoch 116/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7574 - categorical_crossentropy: 0.2370 - accuracy: 0.9366 - val_loss: 1.4774 - val_categorical_crossentropy: 0.9570 - val_accuracy: 0.7022
# Epoch 117/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7573 - categorical_crossentropy: 0.2370 - accuracy: 0.9365 - val_loss: 1.4775 - val_categorical_crossentropy: 0.9571 - val_accuracy: 0.7016
# Epoch 118/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7584 - categorical_crossentropy: 0.2380 - accuracy: 0.9343 - val_loss: 1.4774 - val_categorical_crossentropy: 0.9570 - val_accuracy: 0.7017
# Epoch 119/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7571 - categorical_crossentropy: 0.2367 - accuracy: 0.9362 - val_loss: 1.4774 - val_categorical_crossentropy: 0.9571 - val_accuracy: 0.7017
# Epoch 120/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7563 - categorical_crossentropy: 0.2360 - accuracy: 0.9355 - val_loss: 1.4774 - val_categorical_crossentropy: 0.9570 - val_accuracy: 0.7019
# Epoch 121/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7566 - categorical_crossentropy: 0.2363 - accuracy: 0.9364 - val_loss: 1.4782 - val_categorical_crossentropy: 0.9579 - val_accuracy: 0.7015
# Epoch 122/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7556 - categorical_crossentropy: 0.2352 - accuracy: 0.9373 - val_loss: 1.4784 - val_categorical_crossentropy: 0.9581 - val_accuracy: 0.7020
# Epoch 123/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7551 - categorical_crossentropy: 0.2347 - accuracy: 0.9371 - val_loss: 1.4778 - val_categorical_crossentropy: 0.9575 - val_accuracy: 0.7012
# Epoch 124/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7548 - categorical_crossentropy: 0.2345 - accuracy: 0.9372 - val_loss: 1.4791 - val_categorical_crossentropy: 0.9588 - val_accuracy: 0.7020
# Epoch 125/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7563 - categorical_crossentropy: 0.2360 - accuracy: 0.9366 - val_loss: 1.4794 - val_categorical_crossentropy: 0.9591 - val_accuracy: 0.7012
# Epoch 126/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7582 - categorical_crossentropy: 0.2379 - accuracy: 0.9354 - val_loss: 1.4793 - val_categorical_crossentropy: 0.9590 - val_accuracy: 0.7002
# Epoch 127/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7541 - categorical_crossentropy: 0.2338 - accuracy: 0.9368 - val_loss: 1.4797 - val_categorical_crossentropy: 0.9594 - val_accuracy: 0.7015
# Epoch 128/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7546 - categorical_crossentropy: 0.2343 - accuracy: 0.9379 - val_loss: 1.4804 - val_categorical_crossentropy: 0.9601 - val_accuracy: 0.7013
# Epoch 129/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7527 - categorical_crossentropy: 0.2324 - accuracy: 0.9382 - val_loss: 1.4800 - val_categorical_crossentropy: 0.9597 - val_accuracy: 0.7010
# Epoch 130/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7535 - categorical_crossentropy: 0.2332 - accuracy: 0.9385 - val_loss: 1.4803 - val_categorical_crossentropy: 0.9601 - val_accuracy: 0.7006
# Epoch 131/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7551 - categorical_crossentropy: 0.2348 - accuracy: 0.9368 - val_loss: 1.4807 - val_categorical_crossentropy: 0.9605 - val_accuracy: 0.7020
# Epoch 132/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7534 - categorical_crossentropy: 0.2331 - accuracy: 0.9364 - val_loss: 1.4809 - val_categorical_crossentropy: 0.9607 - val_accuracy: 0.7017
# Epoch 133/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7524 - categorical_crossentropy: 0.2322 - accuracy: 0.9382 - val_loss: 1.4816 - val_categorical_crossentropy: 0.9614 - val_accuracy: 0.7019
# Epoch 134/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7537 - categorical_crossentropy: 0.2335 - accuracy: 0.9364 - val_loss: 1.4819 - val_categorical_crossentropy: 0.9616 - val_accuracy: 0.7008
# Epoch 135/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7528 - categorical_crossentropy: 0.2325 - accuracy: 0.9373 - val_loss: 1.4820 - val_categorical_crossentropy: 0.9618 - val_accuracy: 0.7016
# Epoch 136/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7538 - categorical_crossentropy: 0.2336 - accuracy: 0.9368 - val_loss: 1.4813 - val_categorical_crossentropy: 0.9611 - val_accuracy: 0.7024
# Epoch 137/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7529 - categorical_crossentropy: 0.2327 - accuracy: 0.9380 - val_loss: 1.4819 - val_categorical_crossentropy: 0.9617 - val_accuracy: 0.7012
# Epoch 138/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7514 - categorical_crossentropy: 0.2312 - accuracy: 0.9378 - val_loss: 1.4826 - val_categorical_crossentropy: 0.9624 - val_accuracy: 0.7010
# Epoch 139/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7520 - categorical_crossentropy: 0.2318 - accuracy: 0.9373 - val_loss: 1.4820 - val_categorical_crossentropy: 0.9618 - val_accuracy: 0.7021
# Epoch 140/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7516 - categorical_crossentropy: 0.2314 - accuracy: 0.9372 - val_loss: 1.4833 - val_categorical_crossentropy: 0.9631 - val_accuracy: 0.7011
# Epoch 141/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7498 - categorical_crossentropy: 0.2296 - accuracy: 0.9396 - val_loss: 1.4833 - val_categorical_crossentropy: 0.9631 - val_accuracy: 0.7010
# Epoch 142/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7495 - categorical_crossentropy: 0.2293 - accuracy: 0.9398 - val_loss: 1.4838 - val_categorical_crossentropy: 0.9636 - val_accuracy: 0.7009
# Epoch 143/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7509 - categorical_crossentropy: 0.2307 - accuracy: 0.9372 - val_loss: 1.4835 - val_categorical_crossentropy: 0.9634 - val_accuracy: 0.7011
# Epoch 144/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7501 - categorical_crossentropy: 0.2300 - accuracy: 0.9377 - val_loss: 1.4830 - val_categorical_crossentropy: 0.9629 - val_accuracy: 0.7013
# Epoch 145/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7512 - categorical_crossentropy: 0.2311 - accuracy: 0.9377 - val_loss: 1.4838 - val_categorical_crossentropy: 0.9637 - val_accuracy: 0.7015
# Epoch 146/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7513 - categorical_crossentropy: 0.2312 - accuracy: 0.9378 - val_loss: 1.4857 - val_categorical_crossentropy: 0.9655 - val_accuracy: 0.7016
# Epoch 147/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7513 - categorical_crossentropy: 0.2312 - accuracy: 0.9374 - val_loss: 1.4845 - val_categorical_crossentropy: 0.9644 - val_accuracy: 0.6997
# Epoch 148/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7501 - categorical_crossentropy: 0.2300 - accuracy: 0.9383 - val_loss: 1.4858 - val_categorical_crossentropy: 0.9657 - val_accuracy: 0.7013
# Epoch 149/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7487 - categorical_crossentropy: 0.2286 - accuracy: 0.9380 - val_loss: 1.4846 - val_categorical_crossentropy: 0.9645 - val_accuracy: 0.7015
# Epoch 150/150
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7505 - categorical_crossentropy: 0.2304 - accuracy: 0.9384 - val_loss: 1.4857 - val_categorical_crossentropy: 0.9657 - val_accuracy: 0.7011

# %%
#lr 5e-3 to 30 then 1e-4 to 60 then 1e-5
plt.plot(range(0,100), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,100), history.history['loss'], '-ok',c='r');

# %%
#lr 5e-3 to 70 then 1e-4 to 140 then 1e-5
plt.plot(range(0,300), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,300), history.history['loss'], '-ok',c='r');

# %%
#lr 5e-3 to 120 then 1e-4 to 180 then 1e-5
plt.plot(range(0,300), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,300), history.history['loss'], '-ok',c='r');

# %%
#lr 1e-3 throughout
plt.plot(range(0,250), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,250), history.history['loss'], '-ok',c='r');

# %%
#model.compile(loss='categorical_crossentropy',
#              optimizer=SGD(momentum=.9,lr=5e-3),
#              metrics=['categorical_crossentropy','accuracy'])
history=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=250,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/250
# 50000/50000 [==============================] - 78s 2ms/sample - loss: 2.6929 - categorical_crossentropy: 2.0840 - accuracy: 0.2365 - val_loss: 2.5817 - val_categorical_crossentropy: 1.9732 - val_accuracy: 0.2675
# Epoch 2/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.5005 - categorical_crossentropy: 1.8925 - accuracy: 0.3130 - val_loss: 2.4382 - val_categorical_crossentropy: 1.8306 - val_accuracy: 0.3365
# Epoch 3/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.4168 - categorical_crossentropy: 1.8098 - accuracy: 0.3431 - val_loss: 2.3662 - val_categorical_crossentropy: 1.7596 - val_accuracy: 0.3684
# Epoch 4/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.3559 - categorical_crossentropy: 1.7499 - accuracy: 0.3637 - val_loss: 2.3240 - val_categorical_crossentropy: 1.7185 - val_accuracy: 0.3813
# Epoch 5/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.3105 - categorical_crossentropy: 1.7054 - accuracy: 0.3775 - val_loss: 2.2800 - val_categorical_crossentropy: 1.6754 - val_accuracy: 0.3917
# Epoch 6/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.2747 - categorical_crossentropy: 1.6706 - accuracy: 0.3899 - val_loss: 2.2435 - val_categorical_crossentropy: 1.6399 - val_accuracy: 0.4013
# Epoch 7/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.2412 - categorical_crossentropy: 1.6380 - accuracy: 0.4014 - val_loss: 2.2150 - val_categorical_crossentropy: 1.6123 - val_accuracy: 0.4124
# Epoch 8/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.2090 - categorical_crossentropy: 1.6068 - accuracy: 0.4138 - val_loss: 2.1921 - val_categorical_crossentropy: 1.5905 - val_accuracy: 0.4203
# Epoch 9/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.1766 - categorical_crossentropy: 1.5754 - accuracy: 0.4253 - val_loss: 2.1517 - val_categorical_crossentropy: 1.5510 - val_accuracy: 0.4322
# Epoch 10/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.1461 - categorical_crossentropy: 1.5458 - accuracy: 0.4385 - val_loss: 2.1376 - val_categorical_crossentropy: 1.5379 - val_accuracy: 0.4361
# Epoch 11/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.1160 - categorical_crossentropy: 1.5167 - accuracy: 0.4491 - val_loss: 2.0969 - val_categorical_crossentropy: 1.4982 - val_accuracy: 0.4511
# Epoch 12/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.0870 - categorical_crossentropy: 1.4887 - accuracy: 0.4602 - val_loss: 2.0722 - val_categorical_crossentropy: 1.4744 - val_accuracy: 0.4626
# Epoch 13/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.0574 - categorical_crossentropy: 1.4601 - accuracy: 0.4732 - val_loss: 2.0411 - val_categorical_crossentropy: 1.4443 - val_accuracy: 0.4732
# Epoch 14/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.0282 - categorical_crossentropy: 1.4319 - accuracy: 0.4833 - val_loss: 2.0218 - val_categorical_crossentropy: 1.4260 - val_accuracy: 0.4792
# Epoch 15/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 2.0011 - categorical_crossentropy: 1.4057 - accuracy: 0.4942 - val_loss: 1.9897 - val_categorical_crossentropy: 1.3948 - val_accuracy: 0.4953
# Epoch 16/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.9746 - categorical_crossentropy: 1.3803 - accuracy: 0.5021 - val_loss: 1.9752 - val_categorical_crossentropy: 1.3813 - val_accuracy: 0.4962
# Epoch 17/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.9490 - categorical_crossentropy: 1.3556 - accuracy: 0.5126 - val_loss: 1.9378 - val_categorical_crossentropy: 1.3449 - val_accuracy: 0.5109
# Epoch 18/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.9250 - categorical_crossentropy: 1.3326 - accuracy: 0.5221 - val_loss: 1.9214 - val_categorical_crossentropy: 1.3294 - val_accuracy: 0.5145
# Epoch 19/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.9011 - categorical_crossentropy: 1.3096 - accuracy: 0.5284 - val_loss: 1.9007 - val_categorical_crossentropy: 1.3097 - val_accuracy: 0.5226
# Epoch 20/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.8780 - categorical_crossentropy: 1.2875 - accuracy: 0.5376 - val_loss: 1.8806 - val_categorical_crossentropy: 1.2906 - val_accuracy: 0.5314
# Epoch 21/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.8562 - categorical_crossentropy: 1.2666 - accuracy: 0.5465 - val_loss: 1.8709 - val_categorical_crossentropy: 1.2819 - val_accuracy: 0.5327
# Epoch 22/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.8383 - categorical_crossentropy: 1.2498 - accuracy: 0.5528 - val_loss: 1.8585 - val_categorical_crossentropy: 1.2704 - val_accuracy: 0.5386
# Epoch 23/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.8190 - categorical_crossentropy: 1.2314 - accuracy: 0.5588 - val_loss: 1.8342 - val_categorical_crossentropy: 1.2471 - val_accuracy: 0.5509
# Epoch 24/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7994 - categorical_crossentropy: 1.2128 - accuracy: 0.5654 - val_loss: 1.8208 - val_categorical_crossentropy: 1.2346 - val_accuracy: 0.5507
# Epoch 25/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7840 - categorical_crossentropy: 1.1983 - accuracy: 0.5725 - val_loss: 1.8000 - val_categorical_crossentropy: 1.2148 - val_accuracy: 0.5623
# Epoch 26/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7643 - categorical_crossentropy: 1.1796 - accuracy: 0.5789 - val_loss: 1.8162 - val_categorical_crossentropy: 1.2319 - val_accuracy: 0.5564
# Epoch 27/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7494 - categorical_crossentropy: 1.1655 - accuracy: 0.5828 - val_loss: 1.7881 - val_categorical_crossentropy: 1.2047 - val_accuracy: 0.5639
# Epoch 28/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7354 - categorical_crossentropy: 1.1526 - accuracy: 0.5892 - val_loss: 1.7624 - val_categorical_crossentropy: 1.1800 - val_accuracy: 0.5749
# Epoch 29/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7184 - categorical_crossentropy: 1.1365 - accuracy: 0.5947 - val_loss: 1.7681 - val_categorical_crossentropy: 1.1867 - val_accuracy: 0.5719
# Epoch 30/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.7034 - categorical_crossentropy: 1.1224 - accuracy: 0.5987 - val_loss: 1.7579 - val_categorical_crossentropy: 1.1774 - val_accuracy: 0.5724
# Epoch 31/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6880 - categorical_crossentropy: 1.1080 - accuracy: 0.6051 - val_loss: 1.7321 - val_categorical_crossentropy: 1.1526 - val_accuracy: 0.5811
# Epoch 32/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6728 - categorical_crossentropy: 1.0938 - accuracy: 0.6088 - val_loss: 1.7208 - val_categorical_crossentropy: 1.1422 - val_accuracy: 0.5880
# Epoch 33/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6568 - categorical_crossentropy: 1.0787 - accuracy: 0.6161 - val_loss: 1.7292 - val_categorical_crossentropy: 1.1515 - val_accuracy: 0.5889
# Epoch 34/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6448 - categorical_crossentropy: 1.0677 - accuracy: 0.6203 - val_loss: 1.7513 - val_categorical_crossentropy: 1.1746 - val_accuracy: 0.5748
# Epoch 35/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6288 - categorical_crossentropy: 1.0525 - accuracy: 0.6249 - val_loss: 1.6829 - val_categorical_crossentropy: 1.1071 - val_accuracy: 0.6002
# Epoch 36/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6159 - categorical_crossentropy: 1.0406 - accuracy: 0.6285 - val_loss: 1.6878 - val_categorical_crossentropy: 1.1129 - val_accuracy: 0.5978
# Epoch 37/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.6008 - categorical_crossentropy: 1.0265 - accuracy: 0.6349 - val_loss: 1.6824 - val_categorical_crossentropy: 1.1085 - val_accuracy: 0.6027
# Epoch 38/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5870 - categorical_crossentropy: 1.0136 - accuracy: 0.6383 - val_loss: 1.6786 - val_categorical_crossentropy: 1.1056 - val_accuracy: 0.6041
# Epoch 39/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5736 - categorical_crossentropy: 1.0011 - accuracy: 0.6449 - val_loss: 1.6641 - val_categorical_crossentropy: 1.0921 - val_accuracy: 0.6086
# Epoch 40/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5598 - categorical_crossentropy: 0.9882 - accuracy: 0.6490 - val_loss: 1.6553 - val_categorical_crossentropy: 1.0842 - val_accuracy: 0.6163
# Epoch 41/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5470 - categorical_crossentropy: 0.9764 - accuracy: 0.6503 - val_loss: 1.6372 - val_categorical_crossentropy: 1.0670 - val_accuracy: 0.6219
# Epoch 42/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5311 - categorical_crossentropy: 0.9613 - accuracy: 0.6591 - val_loss: 1.6434 - val_categorical_crossentropy: 1.0742 - val_accuracy: 0.6118
# Epoch 43/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5185 - categorical_crossentropy: 0.9497 - accuracy: 0.6617 - val_loss: 1.6315 - val_categorical_crossentropy: 1.0632 - val_accuracy: 0.6205
# Epoch 44/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.5050 - categorical_crossentropy: 0.9372 - accuracy: 0.6677 - val_loss: 1.6201 - val_categorical_crossentropy: 1.0527 - val_accuracy: 0.6223
# Epoch 45/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4922 - categorical_crossentropy: 0.9253 - accuracy: 0.6713 - val_loss: 1.6276 - val_categorical_crossentropy: 1.0611 - val_accuracy: 0.6212
# Epoch 46/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4782 - categorical_crossentropy: 0.9121 - accuracy: 0.6771 - val_loss: 1.6429 - val_categorical_crossentropy: 1.0773 - val_accuracy: 0.6159
# Epoch 47/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4628 - categorical_crossentropy: 0.8977 - accuracy: 0.6827 - val_loss: 1.6521 - val_categorical_crossentropy: 1.0874 - val_accuracy: 0.6084
# Epoch 48/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4486 - categorical_crossentropy: 0.8844 - accuracy: 0.6885 - val_loss: 1.6052 - val_categorical_crossentropy: 1.0414 - val_accuracy: 0.6245
# Epoch 49/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4369 - categorical_crossentropy: 0.8736 - accuracy: 0.6899 - val_loss: 1.6004 - val_categorical_crossentropy: 1.0376 - val_accuracy: 0.6276
# Epoch 50/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4246 - categorical_crossentropy: 0.8622 - accuracy: 0.6944 - val_loss: 1.6044 - val_categorical_crossentropy: 1.0424 - val_accuracy: 0.6273
# Epoch 51/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.4062 - categorical_crossentropy: 0.8448 - accuracy: 0.7026 - val_loss: 1.5877 - val_categorical_crossentropy: 1.0266 - val_accuracy: 0.6361
# Epoch 52/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3938 - categorical_crossentropy: 0.8332 - accuracy: 0.7076 - val_loss: 1.5669 - val_categorical_crossentropy: 1.0068 - val_accuracy: 0.6408
# Epoch 53/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3818 - categorical_crossentropy: 0.8221 - accuracy: 0.7095 - val_loss: 1.5915 - val_categorical_crossentropy: 1.0323 - val_accuracy: 0.6327
# Epoch 54/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3661 - categorical_crossentropy: 0.8073 - accuracy: 0.7163 - val_loss: 1.5734 - val_categorical_crossentropy: 1.0151 - val_accuracy: 0.6381
# Epoch 55/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3509 - categorical_crossentropy: 0.7930 - accuracy: 0.7192 - val_loss: 1.5922 - val_categorical_crossentropy: 1.0348 - val_accuracy: 0.6325
# Epoch 56/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3330 - categorical_crossentropy: 0.7760 - accuracy: 0.7275 - val_loss: 1.5597 - val_categorical_crossentropy: 1.0031 - val_accuracy: 0.6425
# Epoch 57/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3195 - categorical_crossentropy: 0.7634 - accuracy: 0.7313 - val_loss: 1.5812 - val_categorical_crossentropy: 1.0256 - val_accuracy: 0.6420
# Epoch 58/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.3039 - categorical_crossentropy: 0.7487 - accuracy: 0.7360 - val_loss: 1.5936 - val_categorical_crossentropy: 1.0388 - val_accuracy: 0.6390
# Epoch 59/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2882 - categorical_crossentropy: 0.7339 - accuracy: 0.7421 - val_loss: 1.6258 - val_categorical_crossentropy: 1.0720 - val_accuracy: 0.6270
# Epoch 60/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2738 - categorical_crossentropy: 0.7204 - accuracy: 0.7475 - val_loss: 1.5982 - val_categorical_crossentropy: 1.0452 - val_accuracy: 0.6426
# Epoch 61/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2591 - categorical_crossentropy: 0.7065 - accuracy: 0.7543 - val_loss: 1.5922 - val_categorical_crossentropy: 1.0401 - val_accuracy: 0.6382
# Epoch 62/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2423 - categorical_crossentropy: 0.6906 - accuracy: 0.7598 - val_loss: 1.6128 - val_categorical_crossentropy: 1.0615 - val_accuracy: 0.6346
# Epoch 63/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2247 - categorical_crossentropy: 0.6739 - accuracy: 0.7666 - val_loss: 1.5841 - val_categorical_crossentropy: 1.0337 - val_accuracy: 0.6413
# Epoch 64/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.2120 - categorical_crossentropy: 0.6621 - accuracy: 0.7691 - val_loss: 1.5514 - val_categorical_crossentropy: 1.0019 - val_accuracy: 0.6505
# Epoch 65/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1936 - categorical_crossentropy: 0.6445 - accuracy: 0.7786 - val_loss: 1.6048 - val_categorical_crossentropy: 1.0562 - val_accuracy: 0.6364
# Epoch 66/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1748 - categorical_crossentropy: 0.6266 - accuracy: 0.7802 - val_loss: 1.7151 - val_categorical_crossentropy: 1.1673 - val_accuracy: 0.6136
# Epoch 67/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1614 - categorical_crossentropy: 0.6140 - accuracy: 0.7874 - val_loss: 1.6409 - val_categorical_crossentropy: 1.0940 - val_accuracy: 0.6357
# Epoch 68/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1455 - categorical_crossentropy: 0.5990 - accuracy: 0.7930 - val_loss: 1.6022 - val_categorical_crossentropy: 1.0561 - val_accuracy: 0.6406
# Epoch 69/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1268 - categorical_crossentropy: 0.5812 - accuracy: 0.7998 - val_loss: 1.5970 - val_categorical_crossentropy: 1.0517 - val_accuracy: 0.6449
# Epoch 70/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.1060 - categorical_crossentropy: 0.5612 - accuracy: 0.8085 - val_loss: 1.6551 - val_categorical_crossentropy: 1.1107 - val_accuracy: 0.6303
# Epoch 71/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0912 - categorical_crossentropy: 0.5472 - accuracy: 0.8114 - val_loss: 1.6481 - val_categorical_crossentropy: 1.1046 - val_accuracy: 0.6386
# Epoch 72/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0774 - categorical_crossentropy: 0.5343 - accuracy: 0.8163 - val_loss: 1.6468 - val_categorical_crossentropy: 1.1041 - val_accuracy: 0.6372
# Epoch 73/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0607 - categorical_crossentropy: 0.5184 - accuracy: 0.8216 - val_loss: 1.6913 - val_categorical_crossentropy: 1.1494 - val_accuracy: 0.6307
# Epoch 74/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0439 - categorical_crossentropy: 0.5025 - accuracy: 0.8295 - val_loss: 1.6733 - val_categorical_crossentropy: 1.1322 - val_accuracy: 0.6369
# Epoch 75/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0206 - categorical_crossentropy: 0.4799 - accuracy: 0.8368 - val_loss: 1.6775 - val_categorical_crossentropy: 1.1373 - val_accuracy: 0.6403
# Epoch 76/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 1.0057 - categorical_crossentropy: 0.4659 - accuracy: 0.8421 - val_loss: 1.7069 - val_categorical_crossentropy: 1.1675 - val_accuracy: 0.6337
# Epoch 77/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9914 - categorical_crossentropy: 0.4523 - accuracy: 0.8467 - val_loss: 1.7777 - val_categorical_crossentropy: 1.2390 - val_accuracy: 0.6216
# Epoch 78/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9714 - categorical_crossentropy: 0.4332 - accuracy: 0.8555 - val_loss: 1.9598 - val_categorical_crossentropy: 1.4220 - val_accuracy: 0.5995
# Epoch 79/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9516 - categorical_crossentropy: 0.4141 - accuracy: 0.8611 - val_loss: 1.7626 - val_categorical_crossentropy: 1.2256 - val_accuracy: 0.6277
# Epoch 80/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9379 - categorical_crossentropy: 0.4013 - accuracy: 0.8664 - val_loss: 1.8842 - val_categorical_crossentropy: 1.3479 - val_accuracy: 0.6156
# Epoch 81/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9228 - categorical_crossentropy: 0.3870 - accuracy: 0.8704 - val_loss: 1.8070 - val_categorical_crossentropy: 1.2716 - val_accuracy: 0.6323
# Epoch 82/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.9042 - categorical_crossentropy: 0.3692 - accuracy: 0.8772 - val_loss: 1.7729 - val_categorical_crossentropy: 1.2383 - val_accuracy: 0.6375
# Epoch 83/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8840 - categorical_crossentropy: 0.3498 - accuracy: 0.8856 - val_loss: 1.9414 - val_categorical_crossentropy: 1.4075 - val_accuracy: 0.6087
# Epoch 84/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8748 - categorical_crossentropy: 0.3413 - accuracy: 0.8866 - val_loss: 1.8717 - val_categorical_crossentropy: 1.3386 - val_accuracy: 0.6117
# Epoch 85/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8520 - categorical_crossentropy: 0.3193 - accuracy: 0.8967 - val_loss: 1.9079 - val_categorical_crossentropy: 1.3756 - val_accuracy: 0.5997
# Epoch 86/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8394 - categorical_crossentropy: 0.3075 - accuracy: 0.8999 - val_loss: 1.9275 - val_categorical_crossentropy: 1.3959 - val_accuracy: 0.6197
# Epoch 87/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8298 - categorical_crossentropy: 0.2986 - accuracy: 0.9024 - val_loss: 2.0810 - val_categorical_crossentropy: 1.5502 - val_accuracy: 0.6082
# Epoch 88/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8157 - categorical_crossentropy: 0.2853 - accuracy: 0.9062 - val_loss: 1.9179 - val_categorical_crossentropy: 1.3878 - val_accuracy: 0.6207
# Epoch 89/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.8010 - categorical_crossentropy: 0.2713 - accuracy: 0.9119 - val_loss: 2.0675 - val_categorical_crossentropy: 1.5383 - val_accuracy: 0.6122
# Epoch 90/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7803 - categorical_crossentropy: 0.2514 - accuracy: 0.9203 - val_loss: 1.9677 - val_categorical_crossentropy: 1.4393 - val_accuracy: 0.6268
# Epoch 91/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7667 - categorical_crossentropy: 0.2386 - accuracy: 0.9248 - val_loss: 2.2316 - val_categorical_crossentropy: 1.7038 - val_accuracy: 0.5906
# Epoch 92/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7625 - categorical_crossentropy: 0.2351 - accuracy: 0.9256 - val_loss: 1.9983 - val_categorical_crossentropy: 1.4713 - val_accuracy: 0.6196
# Epoch 93/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7414 - categorical_crossentropy: 0.2148 - accuracy: 0.9341 - val_loss: 2.0761 - val_categorical_crossentropy: 1.5498 - val_accuracy: 0.6083
# Epoch 94/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7319 - categorical_crossentropy: 0.2061 - accuracy: 0.9359 - val_loss: 2.1786 - val_categorical_crossentropy: 1.6531 - val_accuracy: 0.6031
# Epoch 95/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7202 - categorical_crossentropy: 0.1950 - accuracy: 0.9416 - val_loss: 2.0491 - val_categorical_crossentropy: 1.5244 - val_accuracy: 0.6276
# Epoch 96/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7192 - categorical_crossentropy: 0.1948 - accuracy: 0.9399 - val_loss: 2.2758 - val_categorical_crossentropy: 1.7518 - val_accuracy: 0.5930
# Epoch 97/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.7065 - categorical_crossentropy: 0.1828 - accuracy: 0.9449 - val_loss: 2.1467 - val_categorical_crossentropy: 1.6234 - val_accuracy: 0.6126
# Epoch 98/250
# 50000/50000 [==============================] - 66s 1ms/sample - loss: 0.6951 - categorical_crossentropy: 0.1722 - accuracy: 0.9490 - val_loss: 2.1060 - val_categorical_crossentropy: 1.5835 - val_accuracy: 0.6136
# Epoch 99/250
# 50000/50000 [==============================] - 66s 1ms/sample - loss: 0.6817 - categorical_crossentropy: 0.1595 - accuracy: 0.9522 - val_loss: 2.1057 - val_categorical_crossentropy: 1.5839 - val_accuracy: 0.6259
# Epoch 100/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6738 - categorical_crossentropy: 0.1524 - accuracy: 0.9568 - val_loss: 2.4042 - val_categorical_crossentropy: 1.8831 - val_accuracy: 0.6053
# Epoch 101/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6728 - categorical_crossentropy: 0.1521 - accuracy: 0.9555 - val_loss: 2.3736 - val_categorical_crossentropy: 1.8533 - val_accuracy: 0.6122
# Epoch 102/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6720 - categorical_crossentropy: 0.1520 - accuracy: 0.9537 - val_loss: 2.3101 - val_categorical_crossentropy: 1.7905 - val_accuracy: 0.5975
# Epoch 103/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6544 - categorical_crossentropy: 0.1352 - accuracy: 0.9595 - val_loss: 2.2706 - val_categorical_crossentropy: 1.7518 - val_accuracy: 0.6225
# Epoch 104/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6544 - categorical_crossentropy: 0.1359 - accuracy: 0.9593 - val_loss: 2.2243 - val_categorical_crossentropy: 1.7061 - val_accuracy: 0.6255
# Epoch 105/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6423 - categorical_crossentropy: 0.1245 - accuracy: 0.9640 - val_loss: 2.2789 - val_categorical_crossentropy: 1.7615 - val_accuracy: 0.6146
# Epoch 106/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6372 - categorical_crossentropy: 0.1201 - accuracy: 0.9663 - val_loss: 2.2339 - val_categorical_crossentropy: 1.7172 - val_accuracy: 0.6201
# Epoch 107/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6306 - categorical_crossentropy: 0.1142 - accuracy: 0.9673 - val_loss: 2.2584 - val_categorical_crossentropy: 1.7424 - val_accuracy: 0.6218
# Epoch 108/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6189 - categorical_crossentropy: 0.1033 - accuracy: 0.9718 - val_loss: 2.4424 - val_categorical_crossentropy: 1.9271 - val_accuracy: 0.6083
# Epoch 109/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6114 - categorical_crossentropy: 0.0966 - accuracy: 0.9743 - val_loss: 2.2487 - val_categorical_crossentropy: 1.7342 - val_accuracy: 0.6222
# Epoch 110/250
# 50000/50000 [==============================] - 66s 1ms/sample - loss: 0.6134 - categorical_crossentropy: 0.0993 - accuracy: 0.9723 - val_loss: 2.6052 - val_categorical_crossentropy: 2.0915 - val_accuracy: 0.5893
# Epoch 111/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6003 - categorical_crossentropy: 0.0869 - accuracy: 0.9773 - val_loss: 2.3171 - val_categorical_crossentropy: 1.8040 - val_accuracy: 0.6262
# Epoch 112/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6037 - categorical_crossentropy: 0.0910 - accuracy: 0.9753 - val_loss: 2.4234 - val_categorical_crossentropy: 1.9111 - val_accuracy: 0.6237
# Epoch 113/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.6079 - categorical_crossentropy: 0.0959 - accuracy: 0.9733 - val_loss: 2.4848 - val_categorical_crossentropy: 1.9732 - val_accuracy: 0.6046
# Epoch 114/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5975 - categorical_crossentropy: 0.0862 - accuracy: 0.9765 - val_loss: 2.6647 - val_categorical_crossentropy: 2.1538 - val_accuracy: 0.5919
# Epoch 115/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5918 - categorical_crossentropy: 0.0813 - accuracy: 0.9781 - val_loss: 2.3451 - val_categorical_crossentropy: 1.8349 - val_accuracy: 0.6240
# Epoch 116/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5919 - categorical_crossentropy: 0.0821 - accuracy: 0.9775 - val_loss: 2.3525 - val_categorical_crossentropy: 1.8431 - val_accuracy: 0.6279
# Epoch 117/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5818 - categorical_crossentropy: 0.0727 - accuracy: 0.9819 - val_loss: 2.5098 - val_categorical_crossentropy: 2.0011 - val_accuracy: 0.6076
# Epoch 118/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5889 - categorical_crossentropy: 0.0805 - accuracy: 0.9777 - val_loss: 2.3793 - val_categorical_crossentropy: 1.8713 - val_accuracy: 0.6277
# Epoch 119/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5823 - categorical_crossentropy: 0.0747 - accuracy: 0.9797 - val_loss: 2.6256 - val_categorical_crossentropy: 2.1184 - val_accuracy: 0.5966
# Epoch 120/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5782 - categorical_crossentropy: 0.0713 - accuracy: 0.9807 - val_loss: 2.5427 - val_categorical_crossentropy: 2.0362 - val_accuracy: 0.6048
# Epoch 121/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5730 - categorical_crossentropy: 0.0668 - accuracy: 0.9827 - val_loss: 2.4931 - val_categorical_crossentropy: 1.9873 - val_accuracy: 0.6187
# Epoch 122/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5634 - categorical_crossentropy: 0.0579 - accuracy: 0.9861 - val_loss: 2.5161 - val_categorical_crossentropy: 2.0110 - val_accuracy: 0.6089
# Epoch 123/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5643 - categorical_crossentropy: 0.0596 - accuracy: 0.9850 - val_loss: 2.6388 - val_categorical_crossentropy: 2.1345 - val_accuracy: 0.5928
# Epoch 124/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5639 - categorical_crossentropy: 0.0599 - accuracy: 0.9839 - val_loss: 2.4520 - val_categorical_crossentropy: 1.9484 - val_accuracy: 0.6238
# Epoch 125/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5587 - categorical_crossentropy: 0.0554 - accuracy: 0.9859 - val_loss: 2.4924 - val_categorical_crossentropy: 1.9894 - val_accuracy: 0.6114
# Epoch 126/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5573 - categorical_crossentropy: 0.0547 - accuracy: 0.9862 - val_loss: 2.5842 - val_categorical_crossentropy: 2.0819 - val_accuracy: 0.6102
# Epoch 127/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5616 - categorical_crossentropy: 0.0597 - accuracy: 0.9834 - val_loss: 2.5926 - val_categorical_crossentropy: 2.0911 - val_accuracy: 0.5981
# Epoch 128/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5542 - categorical_crossentropy: 0.0530 - accuracy: 0.9861 - val_loss: 2.6041 - val_categorical_crossentropy: 2.1033 - val_accuracy: 0.6083
# Epoch 129/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5446 - categorical_crossentropy: 0.0442 - accuracy: 0.9900 - val_loss: 2.4710 - val_categorical_crossentropy: 1.9710 - val_accuracy: 0.6263
# Epoch 130/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5476 - categorical_crossentropy: 0.0479 - accuracy: 0.9884 - val_loss: 2.4470 - val_categorical_crossentropy: 1.9477 - val_accuracy: 0.6219
# Epoch 131/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5414 - categorical_crossentropy: 0.0424 - accuracy: 0.9903 - val_loss: 2.5161 - val_categorical_crossentropy: 2.0175 - val_accuracy: 0.6259
# Epoch 132/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5452 - categorical_crossentropy: 0.0469 - accuracy: 0.9878 - val_loss: 2.5349 - val_categorical_crossentropy: 2.0371 - val_accuracy: 0.6220
# Epoch 133/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5428 - categorical_crossentropy: 0.0453 - accuracy: 0.9882 - val_loss: 2.5410 - val_categorical_crossentropy: 2.0439 - val_accuracy: 0.6212
# Epoch 134/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5347 - categorical_crossentropy: 0.0379 - accuracy: 0.9918 - val_loss: 2.5921 - val_categorical_crossentropy: 2.0956 - val_accuracy: 0.6239
# Epoch 135/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5422 - categorical_crossentropy: 0.0462 - accuracy: 0.9880 - val_loss: 2.4550 - val_categorical_crossentropy: 1.9593 - val_accuracy: 0.6343
# Epoch 136/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5373 - categorical_crossentropy: 0.0419 - accuracy: 0.9893 - val_loss: 2.5269 - val_categorical_crossentropy: 2.0319 - val_accuracy: 0.6297
# Epoch 137/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5397 - categorical_crossentropy: 0.0451 - accuracy: 0.9885 - val_loss: 2.5583 - val_categorical_crossentropy: 2.0640 - val_accuracy: 0.6204
# Epoch 138/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5347 - categorical_crossentropy: 0.0408 - accuracy: 0.9901 - val_loss: 2.5612 - val_categorical_crossentropy: 2.0676 - val_accuracy: 0.6144
# Epoch 139/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5345 - categorical_crossentropy: 0.0413 - accuracy: 0.9899 - val_loss: 2.5090 - val_categorical_crossentropy: 2.0162 - val_accuracy: 0.6273
# Epoch 140/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5439 - categorical_crossentropy: 0.0514 - accuracy: 0.9852 - val_loss: 2.5679 - val_categorical_crossentropy: 2.0757 - val_accuracy: 0.6222
# Epoch 141/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5360 - categorical_crossentropy: 0.0442 - accuracy: 0.9877 - val_loss: 2.5721 - val_categorical_crossentropy: 2.0806 - val_accuracy: 0.6195
# Epoch 142/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5323 - categorical_crossentropy: 0.0412 - accuracy: 0.9896 - val_loss: 2.7957 - val_categorical_crossentropy: 2.3049 - val_accuracy: 0.6044
# Epoch 143/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5383 - categorical_crossentropy: 0.0479 - accuracy: 0.9863 - val_loss: 2.6966 - val_categorical_crossentropy: 2.2065 - val_accuracy: 0.6075
# Epoch 144/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5408 - categorical_crossentropy: 0.0510 - accuracy: 0.9852 - val_loss: 2.6857 - val_categorical_crossentropy: 2.1963 - val_accuracy: 0.6162
# Epoch 145/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5309 - categorical_crossentropy: 0.0418 - accuracy: 0.9896 - val_loss: 2.5532 - val_categorical_crossentropy: 2.0644 - val_accuracy: 0.6262
# Epoch 146/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5219 - categorical_crossentropy: 0.0335 - accuracy: 0.9924 - val_loss: 2.5605 - val_categorical_crossentropy: 2.0725 - val_accuracy: 0.6180
# Epoch 147/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5227 - categorical_crossentropy: 0.0351 - accuracy: 0.9908 - val_loss: 2.5857 - val_categorical_crossentropy: 2.0984 - val_accuracy: 0.6232
# Epoch 148/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5322 - categorical_crossentropy: 0.0453 - accuracy: 0.9872 - val_loss: 2.7300 - val_categorical_crossentropy: 2.2434 - val_accuracy: 0.6233
# Epoch 149/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5266 - categorical_crossentropy: 0.0403 - accuracy: 0.9885 - val_loss: 2.6437 - val_categorical_crossentropy: 2.1578 - val_accuracy: 0.6132
# Epoch 150/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5233 - categorical_crossentropy: 0.0377 - accuracy: 0.9892 - val_loss: 2.5801 - val_categorical_crossentropy: 2.0948 - val_accuracy: 0.6229
# Epoch 151/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5203 - categorical_crossentropy: 0.0354 - accuracy: 0.9905 - val_loss: 2.6321 - val_categorical_crossentropy: 2.1475 - val_accuracy: 0.6183
# Epoch 152/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5241 - categorical_crossentropy: 0.0399 - accuracy: 0.9890 - val_loss: 2.6136 - val_categorical_crossentropy: 2.1298 - val_accuracy: 0.6298
# Epoch 153/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5174 - categorical_crossentropy: 0.0338 - accuracy: 0.9908 - val_loss: 2.6289 - val_categorical_crossentropy: 2.1457 - val_accuracy: 0.6203
# Epoch 154/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5160 - categorical_crossentropy: 0.0332 - accuracy: 0.9911 - val_loss: 2.8003 - val_categorical_crossentropy: 2.3178 - val_accuracy: 0.6074
# Epoch 155/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5155 - categorical_crossentropy: 0.0333 - accuracy: 0.9914 - val_loss: 2.5938 - val_categorical_crossentropy: 2.1120 - val_accuracy: 0.6210
# Epoch 156/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5114 - categorical_crossentropy: 0.0299 - accuracy: 0.9924 - val_loss: 2.5524 - val_categorical_crossentropy: 2.0713 - val_accuracy: 0.6295
# Epoch 157/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5143 - categorical_crossentropy: 0.0335 - accuracy: 0.9914 - val_loss: 2.7979 - val_categorical_crossentropy: 2.3175 - val_accuracy: 0.6201
# Epoch 158/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5175 - categorical_crossentropy: 0.0374 - accuracy: 0.9899 - val_loss: 2.6674 - val_categorical_crossentropy: 2.1877 - val_accuracy: 0.6218
# Epoch 159/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5092 - categorical_crossentropy: 0.0298 - accuracy: 0.9924 - val_loss: 2.6445 - val_categorical_crossentropy: 2.1654 - val_accuracy: 0.6236
# Epoch 160/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5063 - categorical_crossentropy: 0.0276 - accuracy: 0.9930 - val_loss: 2.9440 - val_categorical_crossentropy: 2.4657 - val_accuracy: 0.6095
# Epoch 161/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5043 - categorical_crossentropy: 0.0263 - accuracy: 0.9937 - val_loss: 2.6385 - val_categorical_crossentropy: 2.1609 - val_accuracy: 0.6225
# Epoch 162/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5058 - categorical_crossentropy: 0.0285 - accuracy: 0.9929 - val_loss: 2.5691 - val_categorical_crossentropy: 2.0921 - val_accuracy: 0.6307
# Epoch 163/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5033 - categorical_crossentropy: 0.0267 - accuracy: 0.9934 - val_loss: 2.6752 - val_categorical_crossentropy: 2.1989 - val_accuracy: 0.6315
# Epoch 164/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5023 - categorical_crossentropy: 0.0264 - accuracy: 0.9936 - val_loss: 2.6331 - val_categorical_crossentropy: 2.1575 - val_accuracy: 0.6259
# Epoch 165/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5064 - categorical_crossentropy: 0.0312 - accuracy: 0.9912 - val_loss: 2.6097 - val_categorical_crossentropy: 2.1348 - val_accuracy: 0.6226
# Epoch 166/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5059 - categorical_crossentropy: 0.0314 - accuracy: 0.9916 - val_loss: 2.6944 - val_categorical_crossentropy: 2.2202 - val_accuracy: 0.6200
# Epoch 167/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5024 - categorical_crossentropy: 0.0285 - accuracy: 0.9923 - val_loss: 2.6037 - val_categorical_crossentropy: 2.1302 - val_accuracy: 0.6297
# Epoch 168/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.5013 - categorical_crossentropy: 0.0281 - accuracy: 0.9927 - val_loss: 2.8244 - val_categorical_crossentropy: 2.3516 - val_accuracy: 0.6224
# Epoch 169/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4968 - categorical_crossentropy: 0.0243 - accuracy: 0.9941 - val_loss: 2.6977 - val_categorical_crossentropy: 2.2256 - val_accuracy: 0.6222
# Epoch 170/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4977 - categorical_crossentropy: 0.0259 - accuracy: 0.9932 - val_loss: 2.7809 - val_categorical_crossentropy: 2.3094 - val_accuracy: 0.6187
# Epoch 171/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4995 - categorical_crossentropy: 0.0284 - accuracy: 0.9920 - val_loss: 2.9506 - val_categorical_crossentropy: 2.4798 - val_accuracy: 0.6116
# Epoch 172/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4929 - categorical_crossentropy: 0.0225 - accuracy: 0.9946 - val_loss: 2.7263 - val_categorical_crossentropy: 2.2562 - val_accuracy: 0.6206
# Epoch 173/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4932 - categorical_crossentropy: 0.0235 - accuracy: 0.9942 - val_loss: 2.6679 - val_categorical_crossentropy: 2.1985 - val_accuracy: 0.6211
# Epoch 174/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4937 - categorical_crossentropy: 0.0247 - accuracy: 0.9934 - val_loss: 2.6678 - val_categorical_crossentropy: 2.1991 - val_accuracy: 0.6312
# Epoch 175/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4900 - categorical_crossentropy: 0.0216 - accuracy: 0.9945 - val_loss: 3.1356 - val_categorical_crossentropy: 2.6675 - val_accuracy: 0.5959
# Epoch 176/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4893 - categorical_crossentropy: 0.0216 - accuracy: 0.9948 - val_loss: 2.6047 - val_categorical_crossentropy: 2.1374 - val_accuracy: 0.6337
# Epoch 177/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4868 - categorical_crossentropy: 0.0198 - accuracy: 0.9951 - val_loss: 2.7358 - val_categorical_crossentropy: 2.2691 - val_accuracy: 0.6191
# Epoch 178/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4860 - categorical_crossentropy: 0.0197 - accuracy: 0.9951 - val_loss: 2.7560 - val_categorical_crossentropy: 2.2900 - val_accuracy: 0.6258
# Epoch 179/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4827 - categorical_crossentropy: 0.0170 - accuracy: 0.9962 - val_loss: 2.6144 - val_categorical_crossentropy: 2.1492 - val_accuracy: 0.6284
# Epoch 180/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4840 - categorical_crossentropy: 0.0191 - accuracy: 0.9956 - val_loss: 2.6848 - val_categorical_crossentropy: 2.2202 - val_accuracy: 0.6209
# Epoch 181/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4845 - categorical_crossentropy: 0.0202 - accuracy: 0.9952 - val_loss: 2.8414 - val_categorical_crossentropy: 2.3775 - val_accuracy: 0.6178
# Epoch 182/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4837 - categorical_crossentropy: 0.0201 - accuracy: 0.9949 - val_loss: 2.6806 - val_categorical_crossentropy: 2.2174 - val_accuracy: 0.6343
# Epoch 183/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4788 - categorical_crossentropy: 0.0159 - accuracy: 0.9965 - val_loss: 2.7023 - val_categorical_crossentropy: 2.2397 - val_accuracy: 0.6338
# Epoch 184/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4771 - categorical_crossentropy: 0.0149 - accuracy: 0.9970 - val_loss: 2.6190 - val_categorical_crossentropy: 2.1571 - val_accuracy: 0.6314
# Epoch 185/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4754 - categorical_crossentropy: 0.0139 - accuracy: 0.9970 - val_loss: 2.7812 - val_categorical_crossentropy: 2.3201 - val_accuracy: 0.6237
# Epoch 186/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4769 - categorical_crossentropy: 0.0161 - accuracy: 0.9963 - val_loss: 2.6778 - val_categorical_crossentropy: 2.2173 - val_accuracy: 0.6319
# Epoch 187/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4784 - categorical_crossentropy: 0.0183 - accuracy: 0.9954 - val_loss: 2.6758 - val_categorical_crossentropy: 2.2160 - val_accuracy: 0.6265
# Epoch 188/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4778 - categorical_crossentropy: 0.0184 - accuracy: 0.9953 - val_loss: 2.9940 - val_categorical_crossentropy: 2.5348 - val_accuracy: 0.6073
# Epoch 189/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4754 - categorical_crossentropy: 0.0167 - accuracy: 0.9963 - val_loss: 2.7683 - val_categorical_crossentropy: 2.3098 - val_accuracy: 0.6287
# Epoch 190/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4775 - categorical_crossentropy: 0.0194 - accuracy: 0.9949 - val_loss: 2.7227 - val_categorical_crossentropy: 2.2649 - val_accuracy: 0.6257
# Epoch 191/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4768 - categorical_crossentropy: 0.0194 - accuracy: 0.9948 - val_loss: 2.8638 - val_categorical_crossentropy: 2.4067 - val_accuracy: 0.6152
# Epoch 192/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4792 - categorical_crossentropy: 0.0225 - accuracy: 0.9941 - val_loss: 2.8023 - val_categorical_crossentropy: 2.3458 - val_accuracy: 0.6265
# Epoch 193/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4737 - categorical_crossentropy: 0.0176 - accuracy: 0.9956 - val_loss: 2.7134 - val_categorical_crossentropy: 2.2576 - val_accuracy: 0.6258
# Epoch 194/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4748 - categorical_crossentropy: 0.0193 - accuracy: 0.9951 - val_loss: 2.8338 - val_categorical_crossentropy: 2.3787 - val_accuracy: 0.6130
# Epoch 195/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4769 - categorical_crossentropy: 0.0221 - accuracy: 0.9939 - val_loss: 2.7275 - val_categorical_crossentropy: 2.2730 - val_accuracy: 0.6309
# Epoch 196/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4863 - categorical_crossentropy: 0.0322 - accuracy: 0.9905 - val_loss: 3.2719 - val_categorical_crossentropy: 2.8181 - val_accuracy: 0.5804
# Epoch 197/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4770 - categorical_crossentropy: 0.0235 - accuracy: 0.9933 - val_loss: 2.7970 - val_categorical_crossentropy: 2.3438 - val_accuracy: 0.6222
# Epoch 198/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4742 - categorical_crossentropy: 0.0213 - accuracy: 0.9939 - val_loss: 2.7152 - val_categorical_crossentropy: 2.2627 - val_accuracy: 0.6222
# Epoch 199/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4746 - categorical_crossentropy: 0.0224 - accuracy: 0.9939 - val_loss: 2.9756 - val_categorical_crossentropy: 2.5237 - val_accuracy: 0.6196
# Epoch 200/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4685 - categorical_crossentropy: 0.0169 - accuracy: 0.9961 - val_loss: 2.7064 - val_categorical_crossentropy: 2.2552 - val_accuracy: 0.6315
# Epoch 201/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4728 - categorical_crossentropy: 0.0219 - accuracy: 0.9938 - val_loss: 2.7058 - val_categorical_crossentropy: 2.2552 - val_accuracy: 0.6274
# Epoch 202/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4757 - categorical_crossentropy: 0.0255 - accuracy: 0.9926 - val_loss: 2.8755 - val_categorical_crossentropy: 2.4256 - val_accuracy: 0.6156
# Epoch 203/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4740 - categorical_crossentropy: 0.0244 - accuracy: 0.9934 - val_loss: 2.6871 - val_categorical_crossentropy: 2.2378 - val_accuracy: 0.6301
# Epoch 204/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4715 - categorical_crossentropy: 0.0224 - accuracy: 0.9935 - val_loss: 2.8712 - val_categorical_crossentropy: 2.4225 - val_accuracy: 0.6195
# Epoch 205/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4730 - categorical_crossentropy: 0.0247 - accuracy: 0.9929 - val_loss: 2.9115 - val_categorical_crossentropy: 2.4635 - val_accuracy: 0.6091
# Epoch 206/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4744 - categorical_crossentropy: 0.0266 - accuracy: 0.9921 - val_loss: 3.0574 - val_categorical_crossentropy: 2.6100 - val_accuracy: 0.6062
# Epoch 207/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4723 - categorical_crossentropy: 0.0252 - accuracy: 0.9925 - val_loss: 2.6533 - val_categorical_crossentropy: 2.2065 - val_accuracy: 0.6283
# Epoch 208/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4688 - categorical_crossentropy: 0.0223 - accuracy: 0.9936 - val_loss: 2.7255 - val_categorical_crossentropy: 2.2793 - val_accuracy: 0.6236
# Epoch 209/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4703 - categorical_crossentropy: 0.0244 - accuracy: 0.9927 - val_loss: 2.6878 - val_categorical_crossentropy: 2.2423 - val_accuracy: 0.6317
# Epoch 210/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4664 - categorical_crossentropy: 0.0211 - accuracy: 0.9937 - val_loss: 3.3050 - val_categorical_crossentropy: 2.8600 - val_accuracy: 0.5887
# Epoch 211/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4649 - categorical_crossentropy: 0.0203 - accuracy: 0.9942 - val_loss: 2.7638 - val_categorical_crossentropy: 2.3195 - val_accuracy: 0.6291
# Epoch 212/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4630 - categorical_crossentropy: 0.0190 - accuracy: 0.9948 - val_loss: 2.7017 - val_categorical_crossentropy: 2.2580 - val_accuracy: 0.6395
# Epoch 213/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4587 - categorical_crossentropy: 0.0153 - accuracy: 0.9958 - val_loss: 2.7595 - val_categorical_crossentropy: 2.3165 - val_accuracy: 0.6280
# Epoch 214/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4553 - categorical_crossentropy: 0.0126 - accuracy: 0.9971 - val_loss: 2.7759 - val_categorical_crossentropy: 2.3336 - val_accuracy: 0.6342
# Epoch 215/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4553 - categorical_crossentropy: 0.0133 - accuracy: 0.9968 - val_loss: 2.7871 - val_categorical_crossentropy: 2.3455 - val_accuracy: 0.6247
# Epoch 216/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4556 - categorical_crossentropy: 0.0142 - accuracy: 0.9965 - val_loss: 2.6575 - val_categorical_crossentropy: 2.2165 - val_accuracy: 0.6397
# Epoch 217/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4514 - categorical_crossentropy: 0.0107 - accuracy: 0.9976 - val_loss: 2.7139 - val_categorical_crossentropy: 2.2736 - val_accuracy: 0.6405
# Epoch 218/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4495 - categorical_crossentropy: 0.0095 - accuracy: 0.9982 - val_loss: 2.6470 - val_categorical_crossentropy: 2.2073 - val_accuracy: 0.6329
# Epoch 219/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4523 - categorical_crossentropy: 0.0130 - accuracy: 0.9967 - val_loss: 2.6965 - val_categorical_crossentropy: 2.2575 - val_accuracy: 0.6301
# Epoch 220/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4519 - categorical_crossentropy: 0.0132 - accuracy: 0.9964 - val_loss: 2.7917 - val_categorical_crossentropy: 2.3534 - val_accuracy: 0.6222
# Epoch 221/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4534 - categorical_crossentropy: 0.0154 - accuracy: 0.9958 - val_loss: 2.9935 - val_categorical_crossentropy: 2.5557 - val_accuracy: 0.6148
# Epoch 222/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4521 - categorical_crossentropy: 0.0147 - accuracy: 0.9961 - val_loss: 2.7768 - val_categorical_crossentropy: 2.3397 - val_accuracy: 0.6293
# Epoch 223/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4516 - categorical_crossentropy: 0.0149 - accuracy: 0.9962 - val_loss: 2.8519 - val_categorical_crossentropy: 2.4155 - val_accuracy: 0.6221
# Epoch 224/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4586 - categorical_crossentropy: 0.0224 - accuracy: 0.9933 - val_loss: 2.7683 - val_categorical_crossentropy: 2.3324 - val_accuracy: 0.6340
# Epoch 225/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4526 - categorical_crossentropy: 0.0171 - accuracy: 0.9953 - val_loss: 3.1133 - val_categorical_crossentropy: 2.6781 - val_accuracy: 0.6023
# Epoch 226/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4511 - categorical_crossentropy: 0.0162 - accuracy: 0.9957 - val_loss: 2.8285 - val_categorical_crossentropy: 2.3939 - val_accuracy: 0.6297
# Epoch 227/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4505 - categorical_crossentropy: 0.0162 - accuracy: 0.9957 - val_loss: 2.8039 - val_categorical_crossentropy: 2.3700 - val_accuracy: 0.6301
# Epoch 228/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4497 - categorical_crossentropy: 0.0161 - accuracy: 0.9956 - val_loss: 2.6797 - val_categorical_crossentropy: 2.2464 - val_accuracy: 0.6358
# Epoch 229/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4458 - categorical_crossentropy: 0.0128 - accuracy: 0.9969 - val_loss: 2.7982 - val_categorical_crossentropy: 2.3655 - val_accuracy: 0.6272
# Epoch 230/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4450 - categorical_crossentropy: 0.0126 - accuracy: 0.9967 - val_loss: 2.8633 - val_categorical_crossentropy: 2.4312 - val_accuracy: 0.6245
# Epoch 231/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4510 - categorical_crossentropy: 0.0193 - accuracy: 0.9945 - val_loss: 2.8763 - val_categorical_crossentropy: 2.4449 - val_accuracy: 0.6199
# Epoch 232/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4464 - categorical_crossentropy: 0.0153 - accuracy: 0.9964 - val_loss: 2.7196 - val_categorical_crossentropy: 2.2888 - val_accuracy: 0.6338
# Epoch 233/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4442 - categorical_crossentropy: 0.0137 - accuracy: 0.9964 - val_loss: 2.7481 - val_categorical_crossentropy: 2.3180 - val_accuracy: 0.6347
# Epoch 234/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4567 - categorical_crossentropy: 0.0268 - accuracy: 0.9917 - val_loss: 2.9275 - val_categorical_crossentropy: 2.4979 - val_accuracy: 0.6184
# Epoch 235/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4556 - categorical_crossentropy: 0.0263 - accuracy: 0.9915 - val_loss: 2.8921 - val_categorical_crossentropy: 2.4631 - val_accuracy: 0.6147
# Epoch 236/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4521 - categorical_crossentropy: 0.0234 - accuracy: 0.9930 - val_loss: 2.9282 - val_categorical_crossentropy: 2.4998 - val_accuracy: 0.6082
# Epoch 237/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4516 - categorical_crossentropy: 0.0235 - accuracy: 0.9928 - val_loss: 3.0345 - val_categorical_crossentropy: 2.6067 - val_accuracy: 0.6141
# Epoch 238/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4457 - categorical_crossentropy: 0.0182 - accuracy: 0.9948 - val_loss: 2.8804 - val_categorical_crossentropy: 2.4532 - val_accuracy: 0.6115
# Epoch 239/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4437 - categorical_crossentropy: 0.0168 - accuracy: 0.9952 - val_loss: 2.6337 - val_categorical_crossentropy: 2.2072 - val_accuracy: 0.6374
# Epoch 240/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4470 - categorical_crossentropy: 0.0207 - accuracy: 0.9939 - val_loss: 3.1186 - val_categorical_crossentropy: 2.6926 - val_accuracy: 0.6113
# Epoch 241/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4502 - categorical_crossentropy: 0.0245 - accuracy: 0.9924 - val_loss: 2.7808 - val_categorical_crossentropy: 2.3553 - val_accuracy: 0.6277
# Epoch 242/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4445 - categorical_crossentropy: 0.0194 - accuracy: 0.9944 - val_loss: 2.7567 - val_categorical_crossentropy: 2.3319 - val_accuracy: 0.6417
# Epoch 243/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4374 - categorical_crossentropy: 0.0129 - accuracy: 0.9969 - val_loss: 2.7675 - val_categorical_crossentropy: 2.3433 - val_accuracy: 0.6364
# Epoch 244/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4411 - categorical_crossentropy: 0.0173 - accuracy: 0.9952 - val_loss: 2.8849 - val_categorical_crossentropy: 2.4613 - val_accuracy: 0.6155
# Epoch 245/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4389 - categorical_crossentropy: 0.0156 - accuracy: 0.9955 - val_loss: 2.8822 - val_categorical_crossentropy: 2.4593 - val_accuracy: 0.6351
# Epoch 246/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4394 - categorical_crossentropy: 0.0167 - accuracy: 0.9948 - val_loss: 2.8362 - val_categorical_crossentropy: 2.4138 - val_accuracy: 0.6327
# Epoch 247/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4400 - categorical_crossentropy: 0.0179 - accuracy: 0.9948 - val_loss: 3.0201 - val_categorical_crossentropy: 2.5984 - val_accuracy: 0.6084
# Epoch 248/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4380 - categorical_crossentropy: 0.0166 - accuracy: 0.9954 - val_loss: 2.9167 - val_categorical_crossentropy: 2.4955 - val_accuracy: 0.6321
# Epoch 249/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4359 - categorical_crossentropy: 0.0151 - accuracy: 0.9959 - val_loss: 2.7688 - val_categorical_crossentropy: 2.3483 - val_accuracy: 0.6409
# Epoch 250/250
# 50000/50000 [==============================] - 67s 1ms/sample - loss: 0.4337 - categorical_crossentropy: 0.0134 - accuracy: 0.9962 - val_loss: 2.7353 - val_categorical_crossentropy: 2.3154 - val_accuracy: 0.6331

# %%
#lr 1e-3 throughout
plt.plot(range(0,250), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,250), history.history['loss'], '-ok',c='r');

# %%
plt.plot(range(0,250), history.history['val_accuracy'], '-ok',c='g');
plt.plot(range(0,250), history.history['accuracy'], '-ok',c='r');

# %%
#lr 5e-3 throughout
plt.plot(range(0,150), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,150), history.history['loss'], '-ok',c='r');

# %%
plt.plot(range(0,150), history.history['val_accuracy'], '-ok',c='g');
plt.plot(range(0,150), history.history['accuracy'], '-ok',c='r');

# %%
plt.plot(range(0,220), history.history['val_loss'], '-ok',c='g');
plt.plot(range(0,220), history.history['loss'], '-ok',c='r');

# %%
plt.plot(range(0,220), history.history['val_accuracy'], '-ok',c='g');
plt.plot(range(0,220), history.history['accuracy'], '-ok',c='r');

# %%
def scheduler(epoch):
  return 1e-9
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
history=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=300,
              validation_data=(x_test, y_test),
              callbacks=[callback],
              shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/300
# 50000/50000 [==============================] - 39s 772us/sample - loss: 0.4879 - categorical_crossentropy: 0.0095 - accuracy: 0.9991 - val_loss: 2.0693 - val_categorical_crossentropy: 1.5910 - val_accuracy: 0.6759
# Epoch 2/300
# 50000/50000 [==============================] - 38s 762us/sample - loss: 0.4887 - categorical_crossentropy: 0.0104 - accuracy: 0.9990 - val_loss: 2.0675 - val_categorical_crossentropy: 1.5892 - val_accuracy: 0.6749
# Epoch 3/300
# 50000/50000 [==============================] - 38s 766us/sample - loss: 0.4887 - categorical_crossentropy: 0.0103 - accuracy: 0.9988 - val_loss: 2.0654 - val_categorical_crossentropy: 1.5871 - val_accuracy: 0.6755
# Epoch 4/300
# 50000/50000 [==============================] - 39s 770us/sample - loss: 0.4884 - categorical_crossentropy: 0.0100 - accuracy: 0.9991 - val_loss: 2.0660 - val_categorical_crossentropy: 1.5877 - val_accuracy: 0.6736
# Epoch 5/300
# 50000/50000 [==============================] - 38s 763us/sample - loss: 0.4885 - categorical_crossentropy: 0.0102 - accuracy: 0.9991 - val_loss: 2.0630 - val_categorical_crossentropy: 1.5847 - val_accuracy: 0.6742
# Epoch 6/300
# 50000/50000 [==============================] - 38s 765us/sample - loss: 0.4893 - categorical_crossentropy: 0.0110 - accuracy: 0.9989 - val_loss: 2.0651 - val_categorical_crossentropy: 1.5868 - val_accuracy: 0.6750
# Epoch 7/300
# 50000/50000 [==============================] - 38s 768us/sample - loss: 0.4881 - categorical_crossentropy: 0.0098 - accuracy: 0.9992 - val_loss: 2.0663 - val_categorical_crossentropy: 1.5879 - val_accuracy: 0.6766
# Epoch 8/300
# 50000/50000 [==============================] - 38s 765us/sample - loss: 0.4887 - categorical_crossentropy: 0.0103 - accuracy: 0.9990 - val_loss: 2.0657 - val_categorical_crossentropy: 1.5874 - val_accuracy: 0.6748
# Epoch 9/300
# 50000/50000 [==============================] - 38s 765us/sample - loss: 0.4880 - categorical_crossentropy: 0.0096 - accuracy: 0.9990 - val_loss: 2.0654 - val_categorical_crossentropy: 1.5871 - val_accuracy: 0.6741
# Epoch 10/300
# 50000/50000 [==============================] - 38s 765us/sample - loss: 0.4882 - categorical_crossentropy: 0.0098 - accuracy: 0.9991 - val_loss: 2.0630 - val_categorical_crossentropy: 1.5846 - val_accuracy: 0.6759
# Epoch 11/300
# 50000/50000 [==============================] - 38s 765us/sample - loss: 0.4882 - categorical_crossentropy: 0.0099 - accuracy: 0.9989 - val_loss: 2.0656 - val_categorical_crossentropy: 1.5872 - val_accuracy: 0.6767
# Epoch 12/300
# 26240/50000 [==============>...............] - ETA: 17s - loss: 0.4880 - categorical_crossentropy: 0.0096 - accuracy: 0.9994
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-24c48bdfe4d5> in <module>()
#       7               validation_data=(x_test, y_test),
#       8               callbacks=[callback],
# ----> 9               shuffle=True)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     641         max_queue_size=max_queue_size,
#     642         workers=workers,
# --> 643         use_multiprocessing=use_multiprocessing)
#     644
#     645   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     662         validation_steps=validation_steps,
#     663         validation_freq=validation_freq,
# --> 664         steps_name='steps_per_epoch')
#     665
#     666   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     381
#     382         # Get outputs.
# --> 383         batch_outs = f(ins_batch)
#     384         if not isinstance(batch_outs, list):
#     385           batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3508         value = math_ops.cast(value, tensor.dtype)
#    3509       converted_inputs.append(value)
# -> 3510     outputs = self._graph_fn(*converted_inputs)
#    3511
#    3512     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#     570       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     571           list(kwargs.keys()), list(self._arg_keywords)))
# --> 572     return self._call_flat(args)
#     573
#     574   def _filtered_call(self, args, kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args)
#     669     # Only need to override the gradient in graph mode and when we have outputs.
#     670     if context.executing_eagerly() or not self.outputs:
# --> 671       outputs = self._inference_function.call(ctx, args)
#     672     else:
#     673       self._register_gradient()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args)
#     443             attrs=("executor_type", executor_type,
#     444                    "config_proto", config),
# --> 445             ctx=ctx)
#     446       # Replace empty list with None
#     447       outputs = outputs or None
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
